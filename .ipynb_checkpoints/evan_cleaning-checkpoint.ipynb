# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress


# File to Load (Remember to change these)
energy_data = "Data files/duke_energy_2010.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data

households = pd.read_csv("Data/duke_energy_2010.csv")
households.head()
# Out:
#      zip  SAMPLE_ID  SAMPLE_ENERGY  SAMPLE_USAGE  SAMPLE_REVENUE  \
# 0  34689   40414551          21156   1763.000000     3141.989990
# 1  34653   40418276           3952    329.329987      586.179993
# 2  33837   40409966          19189   1599.079956     2664.229980
# 3  33870   40410026          16647   1387.250000     2145.000000
# 4  33872   30312281          10374    864.500000     1359.869995
#
#    SAMPLE_HHAGE SAMPLE_INC  SAMPLE_REGION  SAMPLE_ACCOUNT_ACTIVATION_DATE  \
# 0             6          7  SOUTH COASTAL                               0
# 1             5          6  SOUTH COASTAL                               0
# 2             6          7  SOUTH CENTRAL                               0
# 3             5          6  SOUTH CENTRAL                               0
# 4             7          3  SOUTH CENTRAL                               0
#
#    SAMPLE_MAILING_ADDRESS  ... highenergyproblem futurelifeconcern  ccreal  \
# 0        502 WHITE OAK DR  ...              10.0               9.0    10.0
# 1         10141 BRIAR CIR  ...              10.0              10.0    10.0
# 2      530 VISTA OAKS WAY  ...              10.0              10.0     2.0
# 3          2315 AVALON RD  ...               9.0               9.0     1.0
# 4  3513 INDIAN SUMMER TRL  ...               NaN               NaN     NaN
#
#   scarce nuclear solar  wind muchasican  futurepower  phev
# 0   10.0    10.0  10.0  10.0        7.0          9.0   9.0
# 1    9.0     1.0  10.0  10.0        9.0          5.0   4.0
# 2   10.0    10.0   8.0   8.0        6.0          8.0  10.0
# 3    6.0     9.0   9.0   7.0        4.0          4.0   5.0
# 4    NaN     NaN   NaN   NaN        NaN          NaN   NaN
#
# [5 rows x 131 columns]

# %%
# Create test data set with values, attitudes, beliefs. 
attitudes = households[['green', 'payattn', 'considerproduct', 'veryhotdays', 'firstone' , \
                        'conscientiousrecycle', 'reduceenergy', 'realeffort', 'willingchanges', \
                        'highenergyproblem', 'ccreal', 'scarce', 'solar', 'wind', 'muchasican', 'futurepower', 'phev']]

attitudes.head()
# Out:
#    green  payattn  considerproduct  veryhotdays  firstone  \
# 0      0      6.0              8.0          9.0       6.0
# 1      1      8.0              1.0          1.0       1.0
# 2      0     10.0              8.0          1.0       NaN
# 3      0      7.0              8.0          6.0       3.0
# 4      0      NaN              NaN          NaN       NaN
#
#    conscientiousrecycle  reduceenergy  realeffort  willingchanges  \
# 0                  10.0          10.0        10.0             9.0
# 1                   NaN          10.0        10.0            10.0
# 2                   1.0           4.0        10.0             3.0
# 3                   7.0           9.0        10.0             8.0
# 4                  10.0          10.0        10.0             NaN
#
#    highenergyproblem  ccreal  scarce  solar  wind  muchasican  futurepower  \
# 0               10.0    10.0    10.0   10.0  10.0         7.0          9.0
# 1               10.0    10.0     9.0   10.0  10.0         9.0          5.0
# 2               10.0     2.0    10.0    8.0   8.0         6.0          8.0
# 3                9.0     1.0     6.0    9.0   7.0         4.0          4.0
# 4                NaN     NaN     NaN    NaN   NaN         NaN          NaN
#
#    phev
# 0   9.0
# 1   4.0
# 2  10.0
# 3   5.0
# 4   NaN

# %%
x_axis = attitudes[['highenergyproblem']]
y_axis = attitudes[['ccreal']]

plt.title("RELATIONSHIP BETWEEN CONCERN ABOUT ENERGY SUPPLY AND CLIMATE CHANGE")
plt.xlabel("Climate Concern")
plt.ylabel("Energy Supply Concern")

(slope, intercept) = linregress(x_axis, y_axis)
fit = slope * x_axis + intercept

fig, ax = plt.subplots()

fig.suptitle("RELATIONSHIP BETWEEN ENERGY SUPPLY CONCERN AND CLIMATE", fontsize=12, fontweight="bold")

ax.set_xlim(0, 10)
ax.set_ylim(0, 10)

ax.set_xlabel("Climate Concern")
ax.set_ylabel("Energy Supply Concern")

ax.plot(x_axis, fake, linewidth=0, marker='o')
ax.plot(x_axis, fit, 'b--')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-a2251066816b> in <module>
#       6 plt.ylabel("Energy Supply Concern")
#       7
# ----> 8 (slope, intercept) = linregress(x_axis, y_axis)
#       9 fit = slope * x_axis + intercept
#      10
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#     100
#     101     # average sum of squares:
# --> 102     ssxm, ssxym, ssyxm, ssym = np.cov(x, y, bias=1).flat
#     103     r_num = ssxym
#     104     r_den = np.sqrt(ssxm * ssym)
#
# ValueError: too many values to unpack (expected 4)

# %%
# Remove missing values

## First diagnose missingess - print total observations for each survey item
# counts only non-missing
total_rows = attitudes.count()
print(total_rows)
# Out:
# green                   4705
# payattn                 4570
# considerproduct         4473
# veryhotdays             4510
# firstone                4536
# conscientiousrecycle    4552
# reduceenergy            4547
# realeffort              4576
# willingchanges          4584
# highenergyproblem       4570
# ccreal                  4589
# scarce                  4515
# solar                   4514
# wind                    4514
# muchasican              4609
# futurepower             4580
# phev                    4551
# dtype: int64

# %%
attitudes_clean= attitudes.dropna(how='any')
total_rows = attitudes_clean.count()
print(total_rows)
# Out:
# green                   4056
# payattn                 4056
# considerproduct         4056
# veryhotdays             4056
# firstone                4056
# conscientiousrecycle    4056
# reduceenergy            4056
# realeffort              4056
# willingchanges          4056
# highenergyproblem       4056
# ccreal                  4056
# scarce                  4056
# solar                   4056
# wind                    4056
# muchasican              4056
# futurepower             4056
# phev                    4056
# dtype: int64

# %%
# # Create indices grouping similar survey items

# Support for renewables
attitudes_clean['renewables'] = attitudes_clean.apply(lambda row: row['solar'] + row['wind'], axis=1)

# Support for conservation

# Green values

# Concern about energy use
# Out:
# C:\Users\evanj\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
