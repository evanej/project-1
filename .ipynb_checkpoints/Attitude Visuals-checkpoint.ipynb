# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import linregress


# Read the City and Ride Data

attitudes = pd.read_csv("Data/duke_energy_2010.csv")
attitudes.head()
# Out:
#      zip  SAMPLE_ID  SAMPLE_ENERGY  SAMPLE_USAGE  SAMPLE_REVENUE  \
# 0  27603   10100106          17765   1480.420044     1899.530029
# 1  27807   10100111          17818   1484.829956     1919.380005
# 2  27540   10100131          18013   1501.079956     1950.459961
# 3  27545   10100146          18062   1505.170044     1819.969971
# 4  27616   10100171          18333   1527.750000     1695.010010
#
#    SAMPLE_HHAGE SAMPLE_INC    SAMPLE_REGION  SAMPLE_ACCOUNT_ACTIVATION_DATE  \
# 0             4          6  NORTHERN REGION                        20070731
# 1             6          4  NORTHERN REGION                        19910523
# 2             3          8  NORTHERN REGION                        20040622
# 3             3          5  NORTHERN REGION                        20000417
# 4             4          3  NORTHERN REGION                        19920313
#
#   SAMPLE_MAILING_ADDRESS  ... ccreal scarce  nuclear solar wind muchasican  \
# 0     180 TRAVEL LITE DR  ...    2.0    5.0      8.0   6.0  6.0       10.0
# 1   7554 SQUIRREL DEN RD  ...    9.0    1.0     10.0  10.0  4.0        8.0
# 2     729 LITTLE LEAF CT  ...    1.0    8.0      5.0   8.0  8.0        4.0
# 3           406 PINE RUN  ...   10.0    9.0      4.0  10.0  8.0        8.0
# 4          3416 TUNAS ST  ...   10.0   10.0     10.0  10.0  7.0        6.0
#
#   futurepower phev  Q7       _merge
# 0         3.0  1.0   5  matched (3)
# 1         9.0  9.0   5  matched (3)
# 2         8.0  5.0   6  matched (3)
# 3         9.0  4.0   3  matched (3)
# 4         7.0  1.0   4  matched (3)
#
# [5 rows x 133 columns]

# %%
# Creating scales based on shared constructs: "greeness" "first adopter" "conserver"

greenness = []

for index, row in attitudes.iterrows():
    greenness.append(row.conscientiousrecycle + row.ccreal + row.reduceenergy + row.willingchanges)

conserver = []

for index, row in attitudes.iterrows():
    conserver.append(row.muchasican + row.realeffort  + row.payattn)
    
firstadopter = []

for index, row in attitudes.iterrows():
    firstadopter.append(row.firstone + row.phev + row.mycellphone)

# %%
attitudes["greenness"]=pd.Series(greenness)/4
attitudes["conserver"]=pd.Series(conserver)/3
attitudes["firstadopter"]=pd.Series(firstadopter)/3

attitudes.head(20)
# Out:
#       zip  SAMPLE_ID  SAMPLE_ENERGY  SAMPLE_USAGE  SAMPLE_REVENUE  \
# 0   27603   10100106          17765   1480.420044     1899.530029
# 1   27807   10100111          17818   1484.829956     1919.380005
# 2   27540   10100131          18013   1501.079956     1950.459961
# 3   27545   10100146          18062   1505.170044     1819.969971
# 4   27616   10100171          18333   1527.750000     1695.010010
# 5   27609   10100211          18734   1561.170044     1853.449951
# 6   27612   10100241          19144   1595.329956     1959.550049
# 7   27573   10100261          19334   1611.170044     2082.909912
# 8   27603   10100276          19417   1618.079956     2001.609985
# 9   27606   10100291          19498   1624.829956     1966.479980
# 10  27856   10100311          19994   1666.170044     2122.000000
# 11  27513   10100316          19995   1666.250000     2092.100098
# 12  27603   10100321          20018   1668.170044     2132.149902
# 13  27581   10100341          20258   1688.170044     2049.840088
# 14  27856   10100381          20582   1715.170044     2192.419922
# 15  27501   10100421          20842   1736.829956     2216.500000
# 16  27610   10100436          21105   1758.750000     2232.149902
# 17  27882   10100446          21200   1766.670044     2134.120117
# 18  27513   10100471          21430   1785.829956     2305.010010
# 19  27603   10100476          21480   1790.000000     2274.580078
#
#     SAMPLE_HHAGE SAMPLE_INC    SAMPLE_REGION  SAMPLE_ACCOUNT_ACTIVATION_DATE  \
# 0              4          6  NORTHERN REGION                        20070731
# 1              6          4  NORTHERN REGION                        19910523
# 2              3          8  NORTHERN REGION                        20040622
# 3              3          5  NORTHERN REGION                        20000417
# 4              4          3  NORTHERN REGION                        19920313
# 5              5          9  NORTHERN REGION                        19920814
# 6              4          0  NORTHERN REGION                        19890727
# 7              5          7  NORTHERN REGION                        20071011
# 8              5          7  NORTHERN REGION                        19871218
# 9              5          6  NORTHERN REGION                        19770610
# 10             3          7  NORTHERN REGION                        20030228
# 11             4          0  NORTHERN REGION                        19991109
# 12             6          6  NORTHERN REGION                        20040813
# 13             5          0  NORTHERN REGION                        20080625
# 14             4          6  NORTHERN REGION                        19960628
# 15             5          5  NORTHERN REGION                        20060721
# 16             3          1  NORTHERN REGION                        20061011
# 17             5          1  NORTHERN REGION                        19911219
# 18             5          0  NORTHERN REGION                        19941222
# 19             3          8  NORTHERN REGION                        20030314
#
#     SAMPLE_MAILING_ADDRESS  ... solar  wind  muchasican futurepower  phev Q7  \
# 0       180 TRAVEL LITE DR  ...   6.0   6.0        10.0         3.0   1.0  5
# 1     7554 SQUIRREL DEN RD  ...  10.0   4.0         8.0         9.0   9.0  5
# 2       729 LITTLE LEAF CT  ...   8.0   8.0         4.0         8.0   5.0  6
# 3             406 PINE RUN  ...  10.0   8.0         8.0         9.0   4.0  3
# 4            3416 TUNAS ST  ...  10.0   7.0         6.0         7.0   1.0  4
# 5        2109 TREVERTON PL  ...   5.0   3.0        10.0         9.0   5.0  5
# 6            2421 BASIL DR  ...   5.0   5.0         6.0         9.0  10.0  6
# 7          510 W GORDON ST  ...  10.0  10.0         8.0         8.0   8.0  5
# 8             537 MAPLE LN  ...   9.0   9.0         8.0         8.0   7.0  5
# 9         4609 WOODSIDE CT  ...   8.0   8.0         7.0         7.0   2.0  5
# 10     1504 GLEN EAGLES CT  ...   7.0   4.0         6.0         8.0   5.0  3
# 11     107 SMITHS KNOLL CT  ...   7.0   7.0         5.0         5.0   5.0  7
# 12          2133 BALBOA RD  ...   9.0   9.0         8.0         8.0   4.0  3
# 13       4042 RANEY WAY DR  ...  10.0  10.0         2.0         8.0   6.0  4
# 14      2565 W CASTALIA RD  ...  10.0  10.0         8.0         8.0   7.0  4
# 15           105 DANNY CIR  ...   5.0   7.0         5.0         5.0   3.0  3
# 16         1111 GATLING ST  ...   6.0   6.0        10.0         8.0   7.0  5
# 17             PO BOX 1348  ...   9.0   9.0         4.0         7.0   1.0  6
# 18       221 MIDENHALL WAY  ...   6.0   7.0         6.0         4.0   4.0  6
# 19  8412 OLD PONDEROSA CIR  ...  10.0  10.0         3.0         8.0  10.0  5
#
#          _merge greenness  conserver  firstadopter
# 0   matched (3)      3.75   8.333333      5.333333
# 1   matched (3)      7.00   7.333333      6.333333
# 2   matched (3)      5.50   6.000000      7.666667
# 3   matched (3)      8.00   8.666667      4.333333
# 4   matched (3)      8.50   7.333333      3.666667
# 5   matched (3)      8.75   9.666667      6.333333
# 6   matched (3)      8.50   8.666667      5.666667
# 7   matched (3)      7.75   7.333333      5.333333
# 8   matched (3)      8.50   8.666667      7.333333
# 9   matched (3)      6.50   7.000000      3.000000
# 10  matched (3)      5.25   7.000000      5.000000
# 11  matched (3)      5.25   5.000000      4.000000
# 12  matched (3)      8.25   7.333333      4.333333
# 13  matched (3)      6.50   4.333333      4.333333
# 14  matched (3)      7.00   9.333333      3.666667
# 15  matched (3)      6.25   7.000000      4.333333
# 16  matched (3)      8.50  10.000000      6.666667
# 17  matched (3)      6.00   5.333333      1.666667
# 18  matched (3)      6.25   4.333333      5.666667
# 19  matched (3)      8.00   5.666667      8.666667
#
# [20 rows x 136 columns]

# %%
# Remove missing values

## First diagnose missingess - print total observations for each survey item
# counts only non-missing
total_rows = attitudes.count()
print(total_rows)
# Out:
# zip                               4705
# SAMPLE_ID                         4705
# SAMPLE_ENERGY                     4705
# SAMPLE_USAGE                      4705
# SAMPLE_REVENUE                    4705
# SAMPLE_HHAGE                      4705
# SAMPLE_INC                        4705
# SAMPLE_REGION                     4705
# SAMPLE_ACCOUNT_ACTIVATION_DATE    4705
# SAMPLE_MAILING_ADDRESS            4705
# SAMPLE_MAILING_CITY               4705
# SAMPLE_MAILING_STATE              4705
# SAMPLE_MAILING_ZIP                4705
# SAMPLE_PRIMARY_PHONE              4705
# SAMPLE_SECONDARY_PHONE            4705
# SAMPLE_PREMISE_ADDRESS            4705
# SAMPLE_PREMISE_CITY               4705
# SAMPLE_PREMISE_STATE              4705
# SAMPLE_PREMISE_ZIP                4705
# SAMPLE_PREMISE_COUNTY             4705
# SAMPLE_MONTHS                     4705
# SAMPLE_DWELLING                   4705
# SAMPLE_FAMCOMP                    4705
# SAMPLE_HHADULTS                   4705
# SAMPLE_HHCHILDS                   4705
# SAMPLE_HHPEOPLE                   4705
# SAMPLE_HOMEOWN                    4705
# SAMPLE_HISPANIC                   4705
# SAMPLE_ADDRYEAR                   4705
# SAMPLE_BALANCED_BILL              4705
#                                   ...
# income150plus                     4705
# incomenonreport                   4705
# green                             4705
# numtvscomputers                   4705
# livingspace                       4705
# payattn                           4570
# considerproduct                   4473
# veryhotdays                       4510
# myright                           4528
# mycellphone                       4291
# firstone                          4536
# conscientiousrecycle              4552
# reduceenergy                      4547
# realeffort                        4576
# willingchanges                    4584
# highenergyproblem                 4570
# futurelifeconcern                 4594
# ccreal                            4589
# scarce                            4515
# nuclear                           4481
# solar                             4514
# wind                              4514
# muchasican                        4609
# futurepower                       4580
# phev                              4551
# Q7                                4705
# _merge                            4705
# greenness                         4413
# conserver                         4463
# firstadopter                      4189
# Length: 136, dtype: int64

# %%
attitudes_clean= attitudes.dropna(subset=['greenness', 'conserver', 'firstadopter'])
total_rows = attitudes_clean.count()
print(total_rows)
# Out:
# zip                               4069
# SAMPLE_ID                         4069
# SAMPLE_ENERGY                     4069
# SAMPLE_USAGE                      4069
# SAMPLE_REVENUE                    4069
# SAMPLE_HHAGE                      4069
# SAMPLE_INC                        4069
# SAMPLE_REGION                     4069
# SAMPLE_ACCOUNT_ACTIVATION_DATE    4069
# SAMPLE_MAILING_ADDRESS            4069
# SAMPLE_MAILING_CITY               4069
# SAMPLE_MAILING_STATE              4069
# SAMPLE_MAILING_ZIP                4069
# SAMPLE_PRIMARY_PHONE              4069
# SAMPLE_SECONDARY_PHONE            4069
# SAMPLE_PREMISE_ADDRESS            4069
# SAMPLE_PREMISE_CITY               4069
# SAMPLE_PREMISE_STATE              4069
# SAMPLE_PREMISE_ZIP                4069
# SAMPLE_PREMISE_COUNTY             4069
# SAMPLE_MONTHS                     4069
# SAMPLE_DWELLING                   4069
# SAMPLE_FAMCOMP                    4069
# SAMPLE_HHADULTS                   4069
# SAMPLE_HHCHILDS                   4069
# SAMPLE_HHPEOPLE                   4069
# SAMPLE_HOMEOWN                    4069
# SAMPLE_HISPANIC                   4069
# SAMPLE_ADDRYEAR                   4069
# SAMPLE_BALANCED_BILL              4069
#                                   ...
# income150plus                     4069
# incomenonreport                   4069
# green                             4069
# numtvscomputers                   4069
# livingspace                       4069
# payattn                           4069
# considerproduct                   4030
# veryhotdays                       4039
# myright                           4041
# mycellphone                       4069
# firstone                          4069
# conscientiousrecycle              4069
# reduceenergy                      4069
# realeffort                        4069
# willingchanges                    4069
# highenergyproblem                 4041
# futurelifeconcern                 4056
# ccreal                            4069
# scarce                            4019
# nuclear                           3997
# solar                             4022
# wind                              4016
# muchasican                        4069
# futurepower                       4057
# phev                              4069
# Q7                                4069
# _merge                            4069
# greenness                         4069
# conserver                         4069
# firstadopter                      4069
# Length: 136, dtype: int64

# %%
attitudes_clean.to_csv("Data/attitudes_clean5.csv", index=False)

# %%
# Calculate Avereges by zip code
zip_att =attitudes_clean.groupby(["zip"]).mean()
#["myright," "ccisreal"]
#"greenness", "conserver", "firstadopter", "incomeonreport"]
zip_att.head()
# Out:
#         SAMPLE_ID  SAMPLE_ENERGY  SAMPLE_USAGE  SAMPLE_REVENUE  SAMPLE_HHAGE  \
# zip
# 0      20205886.0   19051.500000   1587.625000     2026.784973      5.000000
# 27203  14772301.0   12622.615385   1060.595376     1332.591529      4.807692
# 27205  10110873.5   19252.500000   1604.375000     2048.849976      4.000000
# 27207  10112766.0   14575.000000   1214.579956     1569.160034      3.000000
# 27208  10110851.0    6101.000000    508.420013      703.440002      5.000000
#
#        SAMPLE_ACCOUNT_ACTIVATION_DATE  SAMPLE_MAILING_ZIP  SAMPLE_PREMISE_ZIP  \
# zip
# 0                        2.001088e+07        2.800097e+08        0.000000e+00
# 27203                    1.988295e+07        2.720449e+08        2.720348e+08
# 27205                    2.005032e+07        2.720546e+08        2.720505e+08
# 27207                    1.994050e+07        2.720787e+08        2.720787e+08
# 27208                    2.006112e+07        2.720881e+08        2.720881e+08
#
#        SAMPLE_PREMISE_COUNTY  SAMPLE_MONTHS  ...   nuclear  solar      wind  \
# zip                                          ...
# 0                      144.0      12.000000  ...  8.000000    8.5  8.000000
# 27203                  144.0      11.692308  ...  6.846154    8.0  7.961538
# 27205                  144.0      12.000000  ...  6.500000    5.5  3.000000
# 27207                  110.0      12.000000  ...  5.000000    4.0  4.000000
# 27208                  144.0      12.000000  ...  8.000000    8.0  8.000000
#
#        muchasican  futurepower      phev         Q7  greenness  conserver  \
# zip
# 0        6.000000     8.000000  3.500000   6.500000   8.000000   6.333333
# 27203    7.615385     7.961538  5.192308   8.576923   7.221154   7.705128
# 27205    7.500000     7.500000  5.500000   5.000000   6.875000   7.666667
# 27207    6.000000     6.000000  4.000000   9.000000   4.000000   7.000000
# 27208   10.000000    10.000000  3.000000  10.000000   9.250000  10.000000
#
#        firstadopter
# zip
# 0          6.666667
# 27203      4.589744
# 27205      6.000000
# 27207      4.666667
# 27208      5.666667
#
# [5 rows x 105 columns]

# %%
total_rows1 = zip_att.count()
print(total_rows1)
# Out:
# SAMPLE_ID                         500
# SAMPLE_ENERGY                     500
# SAMPLE_USAGE                      500
# SAMPLE_REVENUE                    500
# SAMPLE_HHAGE                      500
# SAMPLE_ACCOUNT_ACTIVATION_DATE    500
# SAMPLE_MAILING_ZIP                500
# SAMPLE_PREMISE_ZIP                500
# SAMPLE_PREMISE_COUNTY             500
# SAMPLE_MONTHS                     500
# SAMPLE_DWELLING                   500
# SAMPLE_FAMCOMP                    500
# SAMPLE_HHADULTS                   500
# SAMPLE_HHCHILDS                   500
# SAMPLE_HHPEOPLE                   500
# SAMPLE_HOMEOWN                    500
# SAMPLE_ADDRYEAR                   500
# SAMPLE_CELL                       500
# SAMPLE_VER_NUM                    500
# SAMPLE_RDM_ID                     500
# SAMPLE_RDM_                       500
# annkwh                            500
# envprotection                     500
# windpriority                      500
# costpriority                      500
# comfortpriority                   500
# takensteps                        500
# CFL                               500
# hiwebuse                          500
# acage                             481
#                                  ...
# income150                         500
# income150plus                     500
# incomenonreport                   500
# green                             500
# numtvscomputers                   500
# livingspace                       500
# payattn                           500
# considerproduct                   499
# veryhotdays                       499
# myright                           499
# mycellphone                       500
# firstone                          500
# conscientiousrecycle              500
# reduceenergy                      500
# realeffort                        500
# willingchanges                    500
# highenergyproblem                 498
# futurelifeconcern                 498
# ccreal                            500
# scarce                            500
# nuclear                           497
# solar                             498
# wind                              497
# muchasican                        500
# futurepower                       500
# phev                              500
# Q7                                500
# greenness                         500
# conserver                         500
# firstadopter                      500
# Length: 105, dtype: int64

# %%
# #Exploratory graphs

x_axis = zip_att[['greenness']]
y_axis = zip_att[['phev']]

plt.title("RELATIONSHIP GREEN ATTITUDES and WILLINGNESS TO ADOPT PHEVs")
plt.xlabel("Green Attitudes")
plt.ylabel("Willingness to Purchase PHEV")
plt.scatter(x_axis, y_axis, marker="o", color="blue", edgecolor="black")

x1 = zip_att.greenness
y1 = zip_att.phev
stats1 = linregress(x1, y1)
m1 = stats1.slope
b1 = stats1.intercept
plt.plot(x1, m1 * x1 + b1, color="black")
plt.show()
plt.savefig("EJ_Attitudes1.png")

# %%
x_axis = zip_att[['greenness']]
y_axis = zip_att[['conserver']]

plt.title("RELATIONSHIP B/W GREEN AND CONSERVATION ATTITUDES")
plt.xlabel("Green Attitudes")
plt.ylabel("Conservation Attitudes")
plt.scatter(x_axis, y_axis, marker="o", color="green", edgecolor="black")

x1 = zip_att.greenness
y1 = zip_att.conserver
stats1 = linregress(x1, y1)
m1 = stats1.slope
b1 = stats1.intercept
plt.plot(x1, m1 * x1 + b1, color="black")

plt.show()
plt.savefig("EJ_Attitudes2.png")

# %%
x_axis = zip_att[['conserver']]
y_axis = zip_att[['firstadopter']]

plt.title("RELATIONSHIP CONSERVATION AND EARLY ADOPTION ATTITUDES")
plt.xlabel("Conservation Attitudes")
plt.ylabel("Early Adopter Attitudes")
plt.scatter(x_axis, y_axis, marker="o", color="purple", edgecolor="black")

x1 = zip_att.conserver
y1 = zip_att.firstadopter
stats1 = linregress(x1, y1)
m1 = stats1.slope
b1 = stats1.intercept
plt.plot(x1, m1 * x1 + b1, color="black")

plt.show()
plt.savefig("EJ_Attitudes3.png")

# %%
x_axis = zip_att[['greenness']]
y_axis = zip_att[['myright']]

plt.title("RELATIONSHIP B/W GREEN AND NON-GREEN ATTITUDES")
plt.xlabel("Conservation Attitudes")
plt.ylabel("Early Adopter Attitudes")
plt.scatter(x_axis, y_axis, marker="o", color="white", edgecolor="black")

x1 = zip_att.conserver
y1 = zip_att.firstadopter
stats1 = linregress(x1, y1)
m1 = stats1.slope
b1 = stats1.intercept
plt.plot(x1, m1 * x1 + b1, color="black")

plt.show()
plt.savefig("EJ_Attitudes4.png")
